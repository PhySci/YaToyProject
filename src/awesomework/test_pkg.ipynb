# %%
from awesomework.train import main as train

# %%
train()
# Out:
# C:\Praktikum\env\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 11.706811111111108
# r2 score is  0.8507278444259585
